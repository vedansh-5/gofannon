# %%
# !pip install git+https://github.com/The-AI-Alliance/gofannon.git@main --quiet
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.5/410.5 kB 7.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 856.7/856.7 kB 25.8 MB/s eta 0:00:00
#   Building wheel for gofannon (pyproject.toml) ... done

# %%
from google.colab import userdata
from gofannon.reasoning.tree_of_thought import TreeOfThought
import json


depth_chart = [
    {'model_name' : "Qwen/Qwen2.5-72B-Instruct",
     'base_url' : "https://api.deepinfra.com/v1/openai",
     'api_key' : userdata.get('deepinfra'),
     'temperature' : 0.3,
     'prompt_appendix' : 'This isnt used at level 0.'
     },
    {'model_name' : "meta-llama/Llama-3.3-70B-Instruct",
     'base_url' : "https://api.deepinfra.com/v1/openai",
     'api_key' : userdata.get('deepinfra'),
     'temperature' : 0.3,
     }
]

tot = TreeOfThought(depth_chart)
result = tot.fn("Develop a climate change mitigation plan", branches=5)
if 'error' in result:
    print("Processing failed. Debug info:")
    print(json.dumps(tot.get_debug_info(), indent=2))
else:
    print("Successful result:", json.dumps(result, indent=2))
# Out:
# Successful result: {
#   "best_branch": {
#     "description": "Implement a carbon tax to incentivize reduction in emissions",
#     "score": 8,
#     "strengths": [
#       "Economic incentive for emission reduction",
#       "Potential revenue stream for governments",
#       "Encourages development of low-carbon technologies",
#       "Simple to implement and administer"
#     ],
#     "weaknesses": [
#       "May disproportionately affect low-income households",
#       "Potential for carbon leakage if not implemented globally",
#       "Difficulty in determining optimal tax rate",
#       "May not address non-CO2 greenhouse gases"
#     ],
#     "next_steps": [
#       "Conduct thorough analysis of tax rate and revenue allocation",
#       "Develop strategies to mitigate regressive effects on low-income households",
#       "Establish international cooperation to prevent carbon leakage",
#       "Monitor and evaluate effectiveness of the carbon tax"
#     ],
#     "deeper_analysis": {
#       "error": "Level 2 not configured in depth_chart"
#     }
#   },
#   "all_branches": [
#     {
#       "description": "Implement a carbon tax to incentivize reduction in emissions",
#       "score": 8,
#       "strengths": [
#         "Economic incentive for emission reduction",
#         "Potential revenue stream for governments",
#         "Encourages development of low-carbon technologies",
#         "Simple to implement and administer"
#       ],
#       "weaknesses": [
#         "May disproportionately affect low-income households",
#         "Potential for carbon leakage if not implemented globally",
#         "Difficulty in determining optimal tax rate",
#         "May not address non-CO2 greenhouse gases"
#       ],
#       "next_steps": [
#         "Conduct thorough analysis of tax rate and revenue allocation",
#         "Develop strategies to mitigate regressive effects on low-income households",
#         "Establish international cooperation to prevent carbon leakage",
#         "Monitor and evaluate effectiveness of the carbon tax"
#       ],
#       "deeper_analysis": {
#         "error": "Level 2 not configured in depth_chart"
#       }
#     },
#     {
#       "description": "Increase investment in renewable energy sources and infrastructure",
#       "score": 8,
#       "strengths": [
#         "Reduces dependence on fossil fuels",
#         "Mitigates climate change by decreasing greenhouse gas emissions",
#         "Creates jobs and stimulates local economies through infrastructure development",
#         "Improves energy security by diversifying sources"
#       ],
#       "weaknesses": [
#         "High upfront costs for infrastructure and technology",
#         "Intermittent energy supply from sources like solar and wind",
#         "Potential land use and environmental concerns",
#         "Requires significant policy and regulatory support"
#       ],
#       "next_steps": [
#         "Conduct thorough cost-benefit analyses and feasibility studies",
#         "Develop and implement policies to support renewable energy integration",
#         "Invest in research and development to improve technology efficiency and affordability",
#         "Engage in public awareness campaigns to build support and understanding"
#       ],
#       "deeper_analysis": {
#         "error": "Level 2 not configured in depth_chart"
#       }
#     },
#     {
#       "description": "Promote reforestation and afforestation projects to enhance carbon sequestration",
#       "score": 8,
#       "strengths": [
#         "Addresses a critical aspect of climate change mitigation",
#         "Reforestation and afforestation can have numerous co-benefits, such as biodiversity conservation and soil erosion prevention",
#         "Can be implemented in various regions and contexts, making it a versatile solution"
#       ],
#       "weaknesses": [
#         "May require significant upfront investments and resources",
#         "Can be challenging to ensure the long-term sustainability and maintenance of reforested areas",
#         "May conflict with other land uses, such as agriculture or urban development"
#       ],
#       "next_steps": [
#         "Conduct thorough assessments to identify areas with the highest potential for carbon sequestration and biodiversity conservation",
#         "Develop and implement effective monitoring and evaluation systems to track the success of reforestation and afforestation projects",
#         "Engage with local communities and stakeholders to ensure their involvement and support in project planning and implementation"
#       ],
#       "deeper_analysis": {
#         "error": "Level 2 not configured in depth_chart"
#       }
#     },
#     {
#       "description": "Develop and enforce stricter regulations on industrial pollution and waste management",
#       "score": 8,
#       "strengths": [
#         "Addresses the root cause of pollution by targeting industrial sources",
#         "Promotes a proactive approach to environmental protection",
#         "Can lead to significant reductions in pollution and waste",
#         "Encourages industries to adopt sustainable practices"
#       ],
#       "weaknesses": [
#         "May face resistance from industries due to increased costs and regulatory burdens",
#         "Requires significant resources and infrastructure for effective enforcement",
#         "May not address pollution from non-industrial sources, such as agricultural or domestic activities",
#         "Can be challenging to develop and implement effective regulations"
#       ],
#       "next_steps": [
#         "Conduct a thorough analysis of existing regulations and identify areas for improvement",
#         "Engage with industries, stakeholders, and communities to develop and refine stricter regulations",
#         "Develop and implement effective enforcement mechanisms, including monitoring and penalty systems",
#         "Provide support and incentives for industries to adopt sustainable practices and reduce pollution"
#       ],
#       "deeper_analysis": {
#         "error": "Level 2 not configured in depth_chart"
#       }
#     },
#     {
#       "description": "Educate the public and promote sustainable practices in daily life and business operations",
#       "score": 8,
#       "strengths": [
#         "Promotes awareness and education on sustainable practices",
#         "Encourages individuals and businesses to adopt environmentally friendly habits",
#         "Can lead to long-term behavioral change and cultural shift",
#         "Supports a holistic approach to sustainability, encompassing both daily life and business operations"
#       ],
#       "weaknesses": [
#         "Lacks specific, measurable goals and objectives",
#         "Does not provide a clear plan for implementation or evaluation",
#         "May not be effective in reaching or engaging with all segments of the population",
#         "Does not address potential barriers or challenges to adopting sustainable practices"
#       ],
#       "next_steps": [
#         "Develop a comprehensive plan with specific, measurable objectives and timelines",
#         "Identify target audiences and tailor education and promotion strategies to their needs and preferences",
#         "Establish partnerships with key stakeholders, including businesses, community organizations, and government agencies",
#         "Develop a system for monitoring and evaluating the effectiveness of education and promotion efforts"
#       ],
#       "deeper_analysis": {
#         "error": "Level 2 not configured in depth_chart"
#       }
#     }
#   ],
#   "debug_info": {
#     "error_context": [
#       {
#         "stage": "deep_analysis_0",
#         "error": "Level 2 not configured in depth_chart"
#       },
#       {
#         "stage": "deep_analysis_1",
#         "error": "Level 2 not configured in depth_chart"
#       },
#       {
#         "stage": "deep_analysis_2",
#         "error": "Level 2 not configured in depth_chart"
#       },
#       {
#         "stage": "deep_analysis_3",
#         "error": "Level 2 not configured in depth_chart"
#       },
#       {
#         "stage": "deep_analysis_4",
#         "error": "Level 2 not configured in depth_chart"
#       }
#     ],
#     "depth_chart_config": [
#       {
#         "model_name": "Qwen/Qwen2.5-72B-Instruct",
#         "base_url": "https://api.deepinfra.com/v1/openai",
#         "api_key": "REDACTED",
#         "temperature": 0.3,
#         "prompt_appendix": "This isnt used at level 0."
#       },
#       {
#         "model_name": "meta-llama/Llama-3.3-70B-Instruct",
#         "base_url": "https://api.deepinfra.com/v1/openai",
#         "api_key": "REDACTED",
#         "temperature": 0.3
#       }
#     ]
#   }
# }

# %%
print(json.dumps( result, indent=2 )  )
# Out:
# {
#   "best_branch": {
#     "description": "Implement a carbon tax to incentivize reduction in emissions",
#     "score": 8,
#     "strengths": [
#       "Economic incentive for emission reduction",
#       "Potential revenue stream for governments",
#       "Encourages development of low-carbon technologies",
#       "Simple to implement and administer"
#     ],
#     "weaknesses": [
#       "May disproportionately affect low-income households",
#       "Potential for carbon leakage if not implemented globally",
#       "Difficulty in determining optimal tax rate",
#       "May not address non-CO2 greenhouse gases"
#     ],
#     "next_steps": [
#       "Conduct thorough analysis of tax rate and revenue allocation",
#       "Develop strategies to mitigate regressive effects on low-income households",
#       "Establish international cooperation to prevent carbon leakage",
#       "Monitor and evaluate effectiveness of the carbon tax"
#     ],
#     "deeper_analysis": {
#       "error": "Level 2 not configured in depth_chart"
#     }
#   },
#   "all_branches": [
#     {
#       "description": "Implement a carbon tax to incentivize reduction in emissions",
#       "score": 8,
#       "strengths": [
#         "Economic incentive for emission reduction",
#         "Potential revenue stream for governments",
#         "Encourages development of low-carbon technologies",
#         "Simple to implement and administer"
#       ],
#       "weaknesses": [
#         "May disproportionately affect low-income households",
#         "Potential for carbon leakage if not implemented globally",
#         "Difficulty in determining optimal tax rate",
#         "May not address non-CO2 greenhouse gases"
#       ],
#       "next_steps": [
#         "Conduct thorough analysis of tax rate and revenue allocation",
#         "Develop strategies to mitigate regressive effects on low-income households",
#         "Establish international cooperation to prevent carbon leakage",
#         "Monitor and evaluate effectiveness of the carbon tax"
#       ],
#       "deeper_analysis": {
#         "error": "Level 2 not configured in depth_chart"
#       }
#     },
#     {
#       "description": "Increase investment in renewable energy sources and infrastructure",
#       "score": 8,
#       "strengths": [
#         "Reduces dependence on fossil fuels",
#         "Mitigates climate change by decreasing greenhouse gas emissions",
#         "Creates jobs and stimulates local economies through infrastructure development",
#         "Improves energy security by diversifying sources"
#       ],
#       "weaknesses": [
#         "High upfront costs for infrastructure and technology",
#         "Intermittent energy supply from sources like solar and wind",
#         "Potential land use and environmental concerns",
#         "Requires significant policy and regulatory support"
#       ],
#       "next_steps": [
#         "Conduct thorough cost-benefit analyses and feasibility studies",
#         "Develop and implement policies to support renewable energy integration",
#         "Invest in research and development to improve technology efficiency and affordability",
#         "Engage in public awareness campaigns to build support and understanding"
#       ],
#       "deeper_analysis": {
#         "error": "Level 2 not configured in depth_chart"
#       }
#     },
#     {
#       "description": "Promote reforestation and afforestation projects to enhance carbon sequestration",
#       "score": 8,
#       "strengths": [
#         "Addresses a critical aspect of climate change mitigation",
#         "Reforestation and afforestation can have numerous co-benefits, such as biodiversity conservation and soil erosion prevention",
#         "Can be implemented in various regions and contexts, making it a versatile solution"
#       ],
#       "weaknesses": [
#         "May require significant upfront investments and resources",
#         "Can be challenging to ensure the long-term sustainability and maintenance of reforested areas",
#         "May conflict with other land uses, such as agriculture or urban development"
#       ],
#       "next_steps": [
#         "Conduct thorough assessments to identify areas with the highest potential for carbon sequestration and biodiversity conservation",
#         "Develop and implement effective monitoring and evaluation systems to track the success of reforestation and afforestation projects",
#         "Engage with local communities and stakeholders to ensure their involvement and support in project planning and implementation"
#       ],
#       "deeper_analysis": {
#         "error": "Level 2 not configured in depth_chart"
#       }
#     },
#     {
#       "description": "Develop and enforce stricter regulations on industrial pollution and waste management",
#       "score": 8,
#       "strengths": [
#         "Addresses the root cause of pollution by targeting industrial sources",
#         "Promotes a proactive approach to environmental protection",
#         "Can lead to significant reductions in pollution and waste",
#         "Encourages industries to adopt sustainable practices"
#       ],
#       "weaknesses": [
#         "May face resistance from industries due to increased costs and regulatory burdens",
#         "Requires significant resources and infrastructure for effective enforcement",
#         "May not address pollution from non-industrial sources, such as agricultural or domestic activities",
#         "Can be challenging to develop and implement effective regulations"
#       ],
#       "next_steps": [
#         "Conduct a thorough analysis of existing regulations and identify areas for improvement",
#         "Engage with industries, stakeholders, and communities to develop and refine stricter regulations",
#         "Develop and implement effective enforcement mechanisms, including monitoring and penalty systems",
#         "Provide support and incentives for industries to adopt sustainable practices and reduce pollution"
#       ],
#       "deeper_analysis": {
#         "error": "Level 2 not configured in depth_chart"
#       }
#     },
#     {
#       "description": "Educate the public and promote sustainable practices in daily life and business operations",
#       "score": 8,
#       "strengths": [
#         "Promotes awareness and education on sustainable practices",
#         "Encourages individuals and businesses to adopt environmentally friendly habits",
#         "Can lead to long-term behavioral change and cultural shift",
#         "Supports a holistic approach to sustainability, encompassing both daily life and business operations"
#       ],
#       "weaknesses": [
#         "Lacks specific, measurable goals and objectives",
#         "Does not provide a clear plan for implementation or evaluation",
#         "May not be effective in reaching or engaging with all segments of the population",
#         "Does not address potential barriers or challenges to adopting sustainable practices"
#       ],
#       "next_steps": [
#         "Develop a comprehensive plan with specific, measurable objectives and timelines",
#         "Identify target audiences and tailor education and promotion strategies to their needs and preferences",
#         "Establish partnerships with key stakeholders, including businesses, community organizations, and government agencies",
#         "Develop a system for monitoring and evaluating the effectiveness of education and promotion efforts"
#       ],
#       "deeper_analysis": {
#         "error": "Level 2 not configured in depth_chart"
#       }
#     }
#   ],
#   "debug_info": {
#     "error_context": [
#       {
#         "stage": "deep_analysis_0",
#         "error": "Level 2 not configured in depth_chart"
#       },
#       {
#         "stage": "deep_analysis_1",
#         "error": "Level 2 not configured in depth_chart"
#       },
#       {
#         "stage": "deep_analysis_2",
#         "error": "Level 2 not configured in depth_chart"
#       },
#       {
#         "stage": "deep_analysis_3",
#         "error": "Level 2 not configured in depth_chart"
#       },
#       {
#         "stage": "deep_analysis_4",
#         "error": "Level 2 not configured in depth_chart"
#       }
#     ],
#     "depth_chart_config": [
#       {
#         "model_name": "Qwen/Qwen2.5-72B-Instruct",
#         "base_url": "https://api.deepinfra.com/v1/openai",
#         "api_key": "REDACTED",
#         "temperature": 0.3,
#         "prompt_appendix": "This isnt used at level 0."
#       },
#       {
#         "model_name": "meta-llama/Llama-3.3-70B-Instruct",
#         "base_url": "https://api.deepinfra.com/v1/openai",
#         "api_key": "REDACTED",
#         "temperature": 0.3
#       }
#     ]
#   }
# }
