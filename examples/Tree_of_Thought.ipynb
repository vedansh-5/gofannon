# %%
# !pip install openai==1.55.3 httpx==0.27.2 --force-reinstall git+https://github.com/The-AI-Alliance/gofannon.git --quiet
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 3.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 389.6/389.6 kB 22.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 4.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 5.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.0/96.0 kB 6.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.6/207.6 kB 15.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.4/70.4 kB 4.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.6/345.6 kB 21.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 431.4/431.4 kB 25.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 15.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 5.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.9/164.9 kB 11.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 5.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.1 MB/s eta 0:00:00
#   Building wheel for gofannon (pyproject.toml) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jupyter-server 1.24.0 requires anyio<4,>=3.1.0, but you have anyio 4.8.0 which is incompatible.

# %%
from google.colab import userdata
from gofannon.reasoning import TreeOfThought
import json


depth_chart = [
    {'model_name' : "Qwen/Qwen2.5-72B-Instruct",
     'base_url' : "https://api.deepinfra.com/v1/openai",
     'api_key' : userdata.get('deepinfra'),
     'temperature' : 0.3,
     'prompt_appendix' : 'This isnt used at level 0.'
     },
    {'model_name' : "meta-llama/Llama-3.3-70B-Instruct",
     'base_url' : "https://api.deepinfra.com/v1/openai",
     'api_key' : userdata.get('deepinfra'),
     'temperature' : 0.3,
     }
]

tot = TreeOfThought(depth_chart)
result = tot.fn("Develop a climate change mitigation plan", branches=5)
if 'error' in result:
    print("Processing failed. Debug info:")
    print(json.dumps(tot.get_debug_info(), indent=2))
else:
    print("Successful result:", json.dumps(result, indent=2))
# Out:
# Successful result: {
#   "best_branch": {
#     "description": "Implement a carbon tax to incentivize reduction in emissions",
#     "score": 8,
#     "strengths": [
#       "Encourages companies and individuals to reduce emissions by increasing the cost of polluting",
#       "Can generate revenue for governments to invest in renewable energy and other sustainability initiatives",
#       "Simple to implement and administer compared to other climate policies",
#       "Can be designed to be progressive, with higher taxes on larger emitters"
#     ],
#     "weaknesses": [
#       "May disproportionately affect low-income households and industries that are heavily reliant on fossil fuels",
#       "Can be difficult to set an optimal tax rate that balances emission reduction with economic growth",
#       "May lead to carbon leakage, where companies relocate to countries with less stringent climate policies",
#       "Requires international cooperation to be effective, which can be challenging to achieve"
#     ],
#     "next_steps": [
#       "Conduct thorough economic and environmental impact assessments to determine the optimal tax rate and structure",
#       "Develop strategies to mitigate the regressive effects of the tax, such as rebating revenue to low-income households",
#       "Establish a system for monitoring and reporting emissions to ensure compliance and accuracy",
#       "Engage in international diplomacy to promote the adoption of similar carbon pricing mechanisms globally"
#     ],
#     "deeper_analysis": {
#       "error": "Level 2 not configured in depth_chart"
#     }
#   },
#   "all_branches": [
#     {
#       "description": "Implement a carbon tax to incentivize reduction in emissions",
#       "score": 8,
#       "strengths": [
#         "Encourages companies and individuals to reduce emissions by increasing the cost of polluting",
#         "Can generate revenue for governments to invest in renewable energy and other sustainability initiatives",
#         "Simple to implement and administer compared to other climate policies",
#         "Can be designed to be progressive, with higher taxes on larger emitters"
#       ],
#       "weaknesses": [
#         "May disproportionately affect low-income households and industries that are heavily reliant on fossil fuels",
#         "Can be difficult to set an optimal tax rate that balances emission reduction with economic growth",
#         "May lead to carbon leakage, where companies relocate to countries with less stringent climate policies",
#         "Requires international cooperation to be effective, which can be challenging to achieve"
#       ],
#       "next_steps": [
#         "Conduct thorough economic and environmental impact assessments to determine the optimal tax rate and structure",
#         "Develop strategies to mitigate the regressive effects of the tax, such as rebating revenue to low-income households",
#         "Establish a system for monitoring and reporting emissions to ensure compliance and accuracy",
#         "Engage in international diplomacy to promote the adoption of similar carbon pricing mechanisms globally"
#       ],
#       "deeper_analysis": {
#         "error": "Level 2 not configured in depth_chart"
#       }
#     },
#     {
#       "description": "Promote renewable energy adoption through subsidies and investment in infrastructure",
#       "score": 8,
#       "strengths": [
#         "Encourages the use of renewable energy sources",
#         "Subsidies can help reduce the financial burden on individuals and businesses",
#         "Investing in infrastructure can create jobs and stimulate local economies",
#         "Can help reduce greenhouse gas emissions and mitigate climate change"
#       ],
#       "weaknesses": [
#         "Subsidies may not be sustainable in the long term and can be subject to political fluctuations",
#         "Infrastructure investment can be costly and may require significant upfront funding",
#         "May not address the root causes of renewable energy adoption barriers, such as lack of awareness or high upfront costs",
#         "Can be vulnerable to corruption and mismanagement of funds"
#       ],
#       "next_steps": [
#         "Conduct a thorough cost-benefit analysis to determine the effectiveness of subsidies and infrastructure investment",
#         "Develop a comprehensive plan to ensure the sustainability of subsidies and infrastructure funding",
#         "Implement measures to increase awareness and education about the benefits of renewable energy",
#         "Establish a system to monitor and evaluate the progress of renewable energy adoption and make adjustments as needed"
#       ],
#       "deeper_analysis": {
#         "error": "Level 2 not configured in depth_chart"
#       }
#     },
#     {
#       "description": "Enhance public transportation systems to reduce reliance on personal vehicles",
#       "score": 8,
#       "strengths": [
#         "Reduces traffic congestion and air pollution",
#         "Increases mobility for low-income and elderly populations",
#         "Encourages sustainable and environmentally friendly transportation options",
#         "Can be cost-effective in the long run"
#       ],
#       "weaknesses": [
#         "Initial investment costs for infrastructure upgrades can be high",
#         "May require significant changes to existing transportation systems and policies",
#         "Public transportation may not be as convenient or accessible as personal vehicles for some users",
#         "Requires coordination and cooperation among multiple stakeholders"
#       ],
#       "next_steps": [
#         "Conduct a thorough analysis of existing public transportation systems to identify areas for improvement",
#         "Develop a comprehensive plan for upgrading and expanding public transportation infrastructure",
#         "Engage with local communities and stakeholders to raise awareness and build support for the initiative",
#         "Explore funding options and potential partnerships with private companies or government agencies"
#       ],
#       "deeper_analysis": {
#         "error": "Level 2 not configured in depth_chart"
#       }
#     },
#     {
#       "description": "Develop and enforce stricter building codes to improve energy efficiency",
#       "score": 8,
#       "strengths": [
#         "Encourages energy-efficient design and construction",
#         "Can reduce energy consumption and greenhouse gas emissions",
#         "Can be implemented through existing regulatory frameworks",
#         "Can create jobs and stimulate local economies through retrofitting and new construction"
#       ],
#       "weaknesses": [
#         "May increase upfront costs for builders and homeowners",
#         "Can be difficult to enforce and monitor compliance",
#         "May not address existing building stock or retrofitting needs",
#         "Can be influenced by lobbying from industry groups or special interests"
#       ],
#       "next_steps": [
#         "Conduct a thorough analysis of existing building codes and energy efficiency standards",
#         "Engage with stakeholders, including builders, architects, and homeowners, to gather feedback and input",
#         "Develop and propose specific, enforceable code changes and standards",
#         "Establish a plan for monitoring and enforcing compliance, including incentives and penalties"
#       ],
#       "deeper_analysis": {
#         "error": "Level 2 not configured in depth_chart"
#       }
#     },
#     {
#       "description": "Educate the public on sustainable practices and the importance of reducing waste",
#       "score": 7,
#       "strengths": [
#         "Raises awareness about sustainable practices",
#         "Encourages public participation in reducing waste",
#         "Can be implemented through various channels such as social media, schools, and community events"
#       ],
#       "weaknesses": [
#         "May not lead to immediate behavioral change",
#         "Requires significant resources and funding to execute effectively",
#         "Can be challenging to measure the impact and effectiveness of public education campaigns"
#       ],
#       "next_steps": [
#         "Develop a comprehensive communication strategy to reach a wider audience",
#         "Collaborate with influencers, schools, and community leaders to amplify the message",
#         "Establish clear goals and metrics to evaluate the success of the public education campaign"
#       ],
#       "deeper_analysis": {
#         "error": "Level 2 not configured in depth_chart"
#       }
#     }
#   ],
#   "debug_info": {
#     "error_context": [
#       {
#         "stage": "deep_analysis_0",
#         "error": "Level 2 not configured in depth_chart"
#       },
#       {
#         "stage": "deep_analysis_1",
#         "error": "Level 2 not configured in depth_chart"
#       },
#       {
#         "stage": "deep_analysis_2",
#         "error": "Level 2 not configured in depth_chart"
#       },
#       {
#         "stage": "deep_analysis_3",
#         "error": "Level 2 not configured in depth_chart"
#       },
#       {
#         "stage": "deep_analysis_4",
#         "error": "Level 2 not configured in depth_chart"
#       }
#     ],
#     "depth_chart_config": [
#       {
#         "model_name": "Qwen/Qwen2.5-72B-Instruct",
#         "base_url": "https://api.deepinfra.com/v1/openai",
#         "api_key": "REDACTED",
#         "temperature": 0.3,
#         "prompt_appendix": "This isnt used at level 0."
#       },
#       {
#         "model_name": "meta-llama/Llama-3.3-70B-Instruct",
#         "base_url": "https://api.deepinfra.com/v1/openai",
#         "api_key": "REDACTED",
#         "temperature": 0.3
#       }
#     ]
#   }
# }

# %%
print(json.dumps( result, indent=2 )  )
# Out:
# {
#   "best_branch": {
#     "description": "Implement a carbon tax to incentivize reduction in emissions",
#     "score": 8,
#     "strengths": [
#       "Encourages companies and individuals to reduce emissions by increasing the cost of polluting",
#       "Can generate revenue for governments to invest in renewable energy and other sustainability initiatives",
#       "Simple to implement and administer compared to other climate policies",
#       "Can be designed to be progressive, with higher taxes on larger emitters"
#     ],
#     "weaknesses": [
#       "May disproportionately affect low-income households and industries that are heavily reliant on fossil fuels",
#       "Can be difficult to set an optimal tax rate that balances emission reduction with economic growth",
#       "May lead to carbon leakage, where companies relocate to countries with less stringent climate policies",
#       "Requires international cooperation to be effective, which can be challenging to achieve"
#     ],
#     "next_steps": [
#       "Conduct thorough economic and environmental impact assessments to determine the optimal tax rate and structure",
#       "Develop strategies to mitigate the regressive effects of the tax, such as rebating revenue to low-income households",
#       "Establish a system for monitoring and reporting emissions to ensure compliance and accuracy",
#       "Engage in international diplomacy to promote the adoption of similar carbon pricing mechanisms globally"
#     ],
#     "deeper_analysis": {
#       "error": "Level 2 not configured in depth_chart"
#     }
#   },
#   "all_branches": [
#     {
#       "description": "Implement a carbon tax to incentivize reduction in emissions",
#       "score": 8,
#       "strengths": [
#         "Encourages companies and individuals to reduce emissions by increasing the cost of polluting",
#         "Can generate revenue for governments to invest in renewable energy and other sustainability initiatives",
#         "Simple to implement and administer compared to other climate policies",
#         "Can be designed to be progressive, with higher taxes on larger emitters"
#       ],
#       "weaknesses": [
#         "May disproportionately affect low-income households and industries that are heavily reliant on fossil fuels",
#         "Can be difficult to set an optimal tax rate that balances emission reduction with economic growth",
#         "May lead to carbon leakage, where companies relocate to countries with less stringent climate policies",
#         "Requires international cooperation to be effective, which can be challenging to achieve"
#       ],
#       "next_steps": [
#         "Conduct thorough economic and environmental impact assessments to determine the optimal tax rate and structure",
#         "Develop strategies to mitigate the regressive effects of the tax, such as rebating revenue to low-income households",
#         "Establish a system for monitoring and reporting emissions to ensure compliance and accuracy",
#         "Engage in international diplomacy to promote the adoption of similar carbon pricing mechanisms globally"
#       ],
#       "deeper_analysis": {
#         "error": "Level 2 not configured in depth_chart"
#       }
#     },
#     {
#       "description": "Promote renewable energy adoption through subsidies and investment in infrastructure",
#       "score": 8,
#       "strengths": [
#         "Encourages the use of renewable energy sources",
#         "Subsidies can help reduce the financial burden on individuals and businesses",
#         "Investing in infrastructure can create jobs and stimulate local economies",
#         "Can help reduce greenhouse gas emissions and mitigate climate change"
#       ],
#       "weaknesses": [
#         "Subsidies may not be sustainable in the long term and can be subject to political fluctuations",
#         "Infrastructure investment can be costly and may require significant upfront funding",
#         "May not address the root causes of renewable energy adoption barriers, such as lack of awareness or high upfront costs",
#         "Can be vulnerable to corruption and mismanagement of funds"
#       ],
#       "next_steps": [
#         "Conduct a thorough cost-benefit analysis to determine the effectiveness of subsidies and infrastructure investment",
#         "Develop a comprehensive plan to ensure the sustainability of subsidies and infrastructure funding",
#         "Implement measures to increase awareness and education about the benefits of renewable energy",
#         "Establish a system to monitor and evaluate the progress of renewable energy adoption and make adjustments as needed"
#       ],
#       "deeper_analysis": {
#         "error": "Level 2 not configured in depth_chart"
#       }
#     },
#     {
#       "description": "Enhance public transportation systems to reduce reliance on personal vehicles",
#       "score": 8,
#       "strengths": [
#         "Reduces traffic congestion and air pollution",
#         "Increases mobility for low-income and elderly populations",
#         "Encourages sustainable and environmentally friendly transportation options",
#         "Can be cost-effective in the long run"
#       ],
#       "weaknesses": [
#         "Initial investment costs for infrastructure upgrades can be high",
#         "May require significant changes to existing transportation systems and policies",
#         "Public transportation may not be as convenient or accessible as personal vehicles for some users",
#         "Requires coordination and cooperation among multiple stakeholders"
#       ],
#       "next_steps": [
#         "Conduct a thorough analysis of existing public transportation systems to identify areas for improvement",
#         "Develop a comprehensive plan for upgrading and expanding public transportation infrastructure",
#         "Engage with local communities and stakeholders to raise awareness and build support for the initiative",
#         "Explore funding options and potential partnerships with private companies or government agencies"
#       ],
#       "deeper_analysis": {
#         "error": "Level 2 not configured in depth_chart"
#       }
#     },
#     {
#       "description": "Develop and enforce stricter building codes to improve energy efficiency",
#       "score": 8,
#       "strengths": [
#         "Encourages energy-efficient design and construction",
#         "Can reduce energy consumption and greenhouse gas emissions",
#         "Can be implemented through existing regulatory frameworks",
#         "Can create jobs and stimulate local economies through retrofitting and new construction"
#       ],
#       "weaknesses": [
#         "May increase upfront costs for builders and homeowners",
#         "Can be difficult to enforce and monitor compliance",
#         "May not address existing building stock or retrofitting needs",
#         "Can be influenced by lobbying from industry groups or special interests"
#       ],
#       "next_steps": [
#         "Conduct a thorough analysis of existing building codes and energy efficiency standards",
#         "Engage with stakeholders, including builders, architects, and homeowners, to gather feedback and input",
#         "Develop and propose specific, enforceable code changes and standards",
#         "Establish a plan for monitoring and enforcing compliance, including incentives and penalties"
#       ],
#       "deeper_analysis": {
#         "error": "Level 2 not configured in depth_chart"
#       }
#     },
#     {
#       "description": "Educate the public on sustainable practices and the importance of reducing waste",
#       "score": 7,
#       "strengths": [
#         "Raises awareness about sustainable practices",
#         "Encourages public participation in reducing waste",
#         "Can be implemented through various channels such as social media, schools, and community events"
#       ],
#       "weaknesses": [
#         "May not lead to immediate behavioral change",
#         "Requires significant resources and funding to execute effectively",
#         "Can be challenging to measure the impact and effectiveness of public education campaigns"
#       ],
#       "next_steps": [
#         "Develop a comprehensive communication strategy to reach a wider audience",
#         "Collaborate with influencers, schools, and community leaders to amplify the message",
#         "Establish clear goals and metrics to evaluate the success of the public education campaign"
#       ],
#       "deeper_analysis": {
#         "error": "Level 2 not configured in depth_chart"
#       }
#     }
#   ],
#   "debug_info": {
#     "error_context": [
#       {
#         "stage": "deep_analysis_0",
#         "error": "Level 2 not configured in depth_chart"
#       },
#       {
#         "stage": "deep_analysis_1",
#         "error": "Level 2 not configured in depth_chart"
#       },
#       {
#         "stage": "deep_analysis_2",
#         "error": "Level 2 not configured in depth_chart"
#       },
#       {
#         "stage": "deep_analysis_3",
#         "error": "Level 2 not configured in depth_chart"
#       },
#       {
#         "stage": "deep_analysis_4",
#         "error": "Level 2 not configured in depth_chart"
#       }
#     ],
#     "depth_chart_config": [
#       {
#         "model_name": "Qwen/Qwen2.5-72B-Instruct",
#         "base_url": "https://api.deepinfra.com/v1/openai",
#         "api_key": "REDACTED",
#         "temperature": 0.3,
#       },
#       {
#         "model_name": "meta-llama/Llama-3.3-70B-Instruct",
#         "base_url": "https://api.deepinfra.com/v1/openai",
#         "api_key": "REDACTED",
#         "temperature": 0.3
#       }
#     ]
#   }
# }
