# %%
# !pip install openai==1.55.3 httpx==0.27.2 --force-reinstall git+https://github.com/The-AI-Alliance/gofannon.git --quiet
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 3.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 389.6/389.6 kB 17.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 5.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 5.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.0/96.0 kB 7.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.6/207.6 kB 16.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.4/70.4 kB 5.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.6/345.6 kB 21.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 431.4/431.4 kB 24.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 18.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 6.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.9/164.9 kB 11.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 5.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.0 MB/s eta 0:00:00
#   Building wheel for gofannon (pyproject.toml) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jupyter-server 1.24.0 requires anyio<4,>=3.1.0, but you have anyio 4.8.0 which is incompatible.

# %%
from google.colab import userdata
from gofannon.reasoning import HierarchicalCoT
import json


depth_chart = [
    {'model_name' : "Qwen/Qwen2.5-72B-Instruct",
     'base_url' : "https://api.deepinfra.com/v1/openai",
     'api_key' : userdata.get('deepinfra'),
     'temperature' : 0.3,
     'prompt_appendix' : 'This isnt used at level 0.'
     },
    {'model_name' : "meta-llama/Llama-3.3-70B-Instruct",
     'base_url' : "https://api.deepinfra.com/v1/openai",
     'api_key' : userdata.get('deepinfra'),
     'temperature' : 0.3,
     },
    {'model_name' : "meta-llama/Llama-3.3-70B-Instruct",
     'base_url' : "https://api.deepinfra.com/v1/openai",
     'api_key' : userdata.get('deepinfra'),
     'temperature' : 0.3,
     }
]

hcot = HierarchicalCoT(depth_chart)
result = hcot.fn("Explain quantum computing", depth= 3)

if 'error' in result:
    print("Processing failed. Debug info:")
    print(json.dumps(hcot.get_debug_info(), indent=2))
else:
    print("Successful result:", json.dumps(result, indent=2))
# Out:
# Successful result: {
#   "title": "Explain Quantum Computing",
#   "sections": [
#     {
#       "title": "Introduction to Quantum Computing",
#       "sections": [
#         {
#           "title": "What is Quantum Computing?",
#           "content": "Quantum computing is a revolutionary technology that uses the principles of quantum mechanics to perform calculations and operations on data. It is based on the concept of qubits, which are the fundamental units of quantum information. Unlike classical bits, which can only exist in a state of 0 or 1, qubits can exist in multiple states simultaneously, allowing for the processing of vast amounts of information in parallel. This property, known as superposition, enables quantum computers to solve complex problems that are intractable or require an unfeasible amount of time to solve using classical computers. Quantum computing has the potential to transform various fields, including cryptography, optimization, and simulation, and is being explored for its applications in fields such as medicine, finance, and climate modeling."
#         },
#         {
#           "title": "Key Principles of Quantum Computing",
#           "content": "The Key Principles of Quantum Computing are based on the unique properties of quantum mechanics. These principles include Superposition, which allows a quantum bit (qubit) to exist in multiple states simultaneously, enabling the processing of vast amounts of information in parallel. Entanglement is another key principle, where two or more qubits become connected, allowing their properties to be correlated regardless of the distance between them. Quantum Measurement is the process of observing a qubit, which causes its superposition to collapse into a single state. Quantum Interference occurs when multiple qubits interact, resulting in the amplification or cancellation of certain states. Lastly, Quantum Parallelism enables quantum computers to perform many calculations simultaneously, making them potentially much faster than classical computers for certain types of problems."
#         },
#         {
#           "title": "Quantum Computing Basics",
#           "content": "Quantum Computing Basics: Quantum computing is based on the principles of quantum mechanics, which explains the behavior of matter and energy at an atomic and subatomic level. The basics of quantum computing involve understanding quantum bits or qubits, superposition, entanglement, and quantum gates. Qubits are the fundamental units of quantum information, which can exist in multiple states simultaneously, known as superposition. Entanglement is a phenomenon where two or more qubits become connected, allowing their properties to be correlated regardless of distance. Quantum gates are the quantum equivalent of logic gates in classical computing, used to manipulate qubits to perform operations. These basics form the foundation of quantum computing, enabling the creation of quantum algorithms and quantum circuits that can solve complex problems exponentially faster than classical computers."
#         }
#       ]
#     },
#     {
#       "title": "Fundamental Concepts",
#       "sections": [
#         {
#           "title": "Introduction to Quantum Mechanics",
#           "content": "Introduction to Quantum Mechanics: Quantum mechanics is a branch of physics that describes the behavior of matter and energy at an atomic and subatomic level. At these scales, classical physics is no longer applicable, and strange, seemingly random phenomena govern the behavior of particles. Key principles include wave-particle duality, where particles can exhibit both wave-like and particle-like behavior; superposition, where a particle can exist in multiple states simultaneously; entanglement, where particles become connected and can affect each other even at vast distances; and uncertainty principle, which states that certain properties of a particle, like position and momentum, cannot be precisely known at the same time. These principles form the foundation of quantum computing, enabling the creation of quantum bits or qubits, which can process multiple possibilities simultaneously, making quantum computing potentially much faster than classical computing for certain types of calculations."
#         },
#         {
#           "title": "Quantum Bits and Gates",
#           "content": {
#             "Quantum Bits and Gates": {
#               "Introduction": "In classical computing, information is represented as bits (0s and 1s). However, in quantum computing, information is represented as quantum bits or qubits. Qubits are unique because they can exist in multiple states simultaneously, which is known as a superposition.",
#               "Qubits": {
#                 "Definition": "A qubit is the fundamental unit of quantum information, analogous to a classical bit.",
#                 "Properties": {
#                   "Superposition": "Qubits can exist in multiple states (0, 1, and both) at the same time.",
#                   "Entanglement": "Qubits can become 'entangled,' meaning their properties are connected, even when separated by large distances."
#                 }
#               },
#               "Quantum Gates": {
#                 "Definition": "Quantum gates are the quantum equivalent of logic gates in classical computing. They are the basic operations that can be performed on qubits.",
#                 "Types": {
#                   "Hadamard Gate": "Applies a Hadamard transformation to a qubit, creating a superposition.",
#                   "Pauli-X Gate": "Performs a bit flip on a qubit, similar to a NOT gate in classical computing.",
#                   "CNOT Gate": "Applies an XOR operation to two qubits, with one qubit acting as control and the other as target."
#                 },
#                 "Purpose": "Quantum gates are used to manipulate qubits, enabling the creation of quantum algorithms and the processing of quantum information."
#               },
#               "Quantum Circuit Model": {
#                 "Definition": "The quantum circuit model is a framework for constructing quantum algorithms using quantum gates.",
#                 "Description": "In this model, qubits are represented as wires, and quantum gates are applied to these wires in a sequence, forming a quantum circuit."
#               }
#             }
#           }
#         },
#         {
#           "title": "Quantum Computing Models",
#           "sections": [
#             {
#               "title": "Circuit Model",
#               "sections": []
#             },
#             {
#               "title": "Adiabatic Model",
#               "sections": []
#             },
#             {
#               "title": "Topological Model",
#               "sections": []
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "title": "Applications and Future Prospects",
#       "sections": [
#         {
#           "title": "Optimization and Simulation",
#           "content": "Optimization and Simulation: Quantum computing has the potential to revolutionize optimization and simulation tasks, which are crucial in various fields such as logistics, finance, and energy management. Quantum computers can efficiently solve complex optimization problems by exploring an exponentially large solution space simultaneously, thanks to quantum parallelism. This capability can be applied to optimize routes for delivery trucks, portfolios for investment, or supply chains for manufacturing. Additionally, quantum computers can simulate complex systems, such as molecular interactions, materials science, and weather patterns, allowing for breakthroughs in fields like drug discovery, materials engineering, and climate modeling. The ability to simulate complex systems can also help in understanding and mitigating the effects of climate change, optimizing energy consumption, and developing more efficient technologies."
#         },
#         {
#           "title": "Cryptography and Cybersecurity",
#           "content": "Cryptography and cybersecurity are critical areas where quantum computing will have a significant impact. Quantum computers can potentially break many encryption algorithms currently in use, compromising the security of online transactions and communication. However, quantum computing also offers new opportunities for creating unbreakable encryption methods, such as quantum key distribution (QKD), which uses quantum mechanics to encode and decode messages. QKD enables secure communication over long distances, making it ideal for high-stakes applications like financial transactions and sensitive data transfer. Furthermore, quantum computers can simulate complex cryptographic systems, allowing for the development of more secure and efficient encryption algorithms. The future of cryptography and cybersecurity will likely involve a combination of quantum-resistant algorithms and QKD to ensure the security of online transactions and communication in a post-quantum world."
#         },
#         {
#           "title": "Artificial Intelligence and Machine Learning",
#           "content": "Artificial Intelligence and Machine Learning: Quantum computing has the potential to revolutionize artificial intelligence and machine learning by enabling the processing of complex algorithms and large datasets at unprecedented speeds. Quantum machine learning can be used to improve the accuracy of predictive models, optimize complex systems, and enable real-time decision-making. Quantum AI can also be applied to areas such as natural language processing, computer vision, and robotics. The integration of quantum computing and AI has the potential to solve complex problems in fields like healthcare, finance, and climate modeling, leading to breakthroughs in areas like disease diagnosis, portfolio optimization, and weather forecasting. Key applications include quantum k-means, quantum support vector machines, and quantum neural networks, which can be used to tackle complex tasks like image recognition, speech recognition, and autonomous vehicles. As quantum computing continues to advance, we can expect to see significant improvements in the field of AI and machine learning, leading to innovative solutions and new opportunities for growth and development."
#         },
#         {
#           "title": "Materials Science and Nanotechnology",
#           "content": "Materials Science and Nanotechnology: Quantum computing has the potential to revolutionize materials science and nanotechnology by simulating the behavior of materials at the atomic and subatomic level. This can lead to the discovery of new materials with unique properties, such as superconductors, nanomaterials, and metamaterials. Quantum computers can also optimize material properties, such as strength, conductivity, and optical properties, by simulating the behavior of materials under different conditions. Additionally, quantum computing can aid in the design of new nanoscale devices, such as quantum dots, nanowires, and graphene-based devices, which have potential applications in fields like energy, electronics, and medicine. The ability to simulate and optimize material properties at the quantum level can also lead to breakthroughs in fields like energy storage, catalysis, and thermoelectrics, enabling the development of more efficient and sustainable technologies."
#         },
#         {
#           "title": "Future Prospects and Challenges",
#           "sections": [
#             {
#               "title": "Quantum Error Correction",
#               "content": "The development of robust quantum error correction techniques is essential for large-scale quantum computing applications."
#             },
#             {
#               "title": "Quantum Computing Hardware",
#               "content": "Advances in quantum computing hardware, such as the development of more reliable and scalable quantum processors, are crucial for the widespread adoption of quantum computing."
#             }
#           ]
#         }
#       ]
#     }
#   ]
# }

# %%
print( hcot.to_markdown(result))
# Out:
# # Explain Quantum Computing
#
# ## Introduction to Quantum Computing
#
# ### What is Quantum Computing?
#
# Quantum computing is a revolutionary technology that uses the principles of quantum mechanics to perform calculations and operations on data. It is based on the concept of qubits, which are the fundamental units of quantum information. Unlike classical bits, which can only exist in a state of 0 or 1, qubits can exist in multiple states simultaneously, allowing for the processing of vast amounts of information in parallel. This property, known as superposition, enables quantum computers to solve complex problems that are intractable or require an unfeasible amount of time to solve using classical computers. Quantum computing has the potential to transform various fields, including cryptography, optimization, and simulation, and is being explored for its applications in fields such as medicine, finance, and climate modeling.
#
# ### Key Principles of Quantum Computing
#
# The Key Principles of Quantum Computing are based on the unique properties of quantum mechanics. These principles include Superposition, which allows a quantum bit (qubit) to exist in multiple states simultaneously, enabling the processing of vast amounts of information in parallel. Entanglement is another key principle, where two or more qubits become connected, allowing their properties to be correlated regardless of the distance between them. Quantum Measurement is the process of observing a qubit, which causes its superposition to collapse into a single state. Quantum Interference occurs when multiple qubits interact, resulting in the amplification or cancellation of certain states. Lastly, Quantum Parallelism enables quantum computers to perform many calculations simultaneously, making them potentially much faster than classical computers for certain types of problems.
#
# ### Quantum Computing Basics
#
# Quantum Computing Basics: Quantum computing is based on the principles of quantum mechanics, which explains the behavior of matter and energy at an atomic and subatomic level. The basics of quantum computing involve understanding quantum bits or qubits, superposition, entanglement, and quantum gates. Qubits are the fundamental units of quantum information, which can exist in multiple states simultaneously, known as superposition. Entanglement is a phenomenon where two or more qubits become connected, allowing their properties to be correlated regardless of distance. Quantum gates are the quantum equivalent of logic gates in classical computing, used to manipulate qubits to perform operations. These basics form the foundation of quantum computing, enabling the creation of quantum algorithms and quantum circuits that can solve complex problems exponentially faster than classical computers.
#
# ## Fundamental Concepts
#
# ### Introduction to Quantum Mechanics
#
# Introduction to Quantum Mechanics: Quantum mechanics is a branch of physics that describes the behavior of matter and energy at an atomic and subatomic level. At these scales, classical physics is no longer applicable, and strange, seemingly random phenomena govern the behavior of particles. Key principles include wave-particle duality, where particles can exhibit both wave-like and particle-like behavior; superposition, where a particle can exist in multiple states simultaneously; entanglement, where particles become connected and can affect each other even at vast distances; and uncertainty principle, which states that certain properties of a particle, like position and momentum, cannot be precisely known at the same time. These principles form the foundation of quantum computing, enabling the creation of quantum bits or qubits, which can process multiple possibilities simultaneously, making quantum computing potentially much faster than classical computing for certain types of calculations.
#
# ### Quantum Bits and Gates
#
# {'Quantum Bits and Gates': {'Introduction': 'In classical computing, information is represented as bits (0s and 1s). However, in quantum computing, information is represented as quantum bits or qubits. Qubits are unique because they can exist in multiple states simultaneously, which is known as a superposition.', 'Qubits': {'Definition': 'A qubit is the fundamental unit of quantum information, analogous to a classical bit.', 'Properties': {'Superposition': 'Qubits can exist in multiple states (0, 1, and both) at the same time.', 'Entanglement': "Qubits can become 'entangled,' meaning their properties are connected, even when separated by large distances."}}, 'Quantum Gates': {'Definition': 'Quantum gates are the quantum equivalent of logic gates in classical computing. They are the basic operations that can be performed on qubits.', 'Types': {'Hadamard Gate': 'Applies a Hadamard transformation to a qubit, creating a superposition.', 'Pauli-X Gate': 'Performs a bit flip on a qubit, similar to a NOT gate in classical computing.', 'CNOT Gate': 'Applies an XOR operation to two qubits, with one qubit acting as control and the other as target.'}, 'Purpose': 'Quantum gates are used to manipulate qubits, enabling the creation of quantum algorithms and the processing of quantum information.'}, 'Quantum Circuit Model': {'Definition': 'The quantum circuit model is a framework for constructing quantum algorithms using quantum gates.', 'Description': 'In this model, qubits are represented as wires, and quantum gates are applied to these wires in a sequence, forming a quantum circuit.'}}}
#
# ### Quantum Computing Models
#
# #### Circuit Model
#
# #### Adiabatic Model
#
# #### Topological Model
#
# ## Applications and Future Prospects
#
# ### Optimization and Simulation
#
# Optimization and Simulation: Quantum computing has the potential to revolutionize optimization and simulation tasks, which are crucial in various fields such as logistics, finance, and energy management. Quantum computers can efficiently solve complex optimization problems by exploring an exponentially large solution space simultaneously, thanks to quantum parallelism. This capability can be applied to optimize routes for delivery trucks, portfolios for investment, or supply chains for manufacturing. Additionally, quantum computers can simulate complex systems, such as molecular interactions, materials science, and weather patterns, allowing for breakthroughs in fields like drug discovery, materials engineering, and climate modeling. The ability to simulate complex systems can also help in understanding and mitigating the effects of climate change, optimizing energy consumption, and developing more efficient technologies.
#
# ### Cryptography and Cybersecurity
#
# Cryptography and cybersecurity are critical areas where quantum computing will have a significant impact. Quantum computers can potentially break many encryption algorithms currently in use, compromising the security of online transactions and communication. However, quantum computing also offers new opportunities for creating unbreakable encryption methods, such as quantum key distribution (QKD), which uses quantum mechanics to encode and decode messages. QKD enables secure communication over long distances, making it ideal for high-stakes applications like financial transactions and sensitive data transfer. Furthermore, quantum computers can simulate complex cryptographic systems, allowing for the development of more secure and efficient encryption algorithms. The future of cryptography and cybersecurity will likely involve a combination of quantum-resistant algorithms and QKD to ensure the security of online transactions and communication in a post-quantum world.
#
# ### Artificial Intelligence and Machine Learning
#
# Artificial Intelligence and Machine Learning: Quantum computing has the potential to revolutionize artificial intelligence and machine learning by enabling the processing of complex algorithms and large datasets at unprecedented speeds. Quantum machine learning can be used to improve the accuracy of predictive models, optimize complex systems, and enable real-time decision-making. Quantum AI can also be applied to areas such as natural language processing, computer vision, and robotics. The integration of quantum computing and AI has the potential to solve complex problems in fields like healthcare, finance, and climate modeling, leading to breakthroughs in areas like disease diagnosis, portfolio optimization, and weather forecasting. Key applications include quantum k-means, quantum support vector machines, and quantum neural networks, which can be used to tackle complex tasks like image recognition, speech recognition, and autonomous vehicles. As quantum computing continues to advance, we can expect to see significant improvements in the field of AI and machine learning, leading to innovative solutions and new opportunities for growth and development.
#
# ### Materials Science and Nanotechnology
#
# Materials Science and Nanotechnology: Quantum computing has the potential to revolutionize materials science and nanotechnology by simulating the behavior of materials at the atomic and subatomic level. This can lead to the discovery of new materials with unique properties, such as superconductors, nanomaterials, and metamaterials. Quantum computers can also optimize material properties, such as strength, conductivity, and optical properties, by simulating the behavior of materials under different conditions. Additionally, quantum computing can aid in the design of new nanoscale devices, such as quantum dots, nanowires, and graphene-based devices, which have potential applications in fields like energy, electronics, and medicine. The ability to simulate and optimize material properties at the quantum level can also lead to breakthroughs in fields like energy storage, catalysis, and thermoelectrics, enabling the development of more efficient and sustainable technologies.
#
# ### Future Prospects and Challenges
#
# #### Quantum Error Correction
#
# The development of robust quantum error correction techniques is essential for large-scale quantum computing applications.
#
# #### Quantum Computing Hardware
#
# Advances in quantum computing hardware, such as the development of more reliable and scalable quantum processors, are crucial for the widespread adoption of quantum computing.
